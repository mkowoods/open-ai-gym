# %%
import gym
#from q_learning import FeedForwardBrain
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/mwoods/Developer/open-ai-gym/venv/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
env = gym.make('FrozenLake-v0')
# Out:
# [2016-12-05 23:21:59,694] Making new env: FrozenLake-v0

# %%
print env
# Out:
# <FrozenLakeEnv instance>

# %%
import q_learning

# %%
reload(q_learning)
brain = q_learning.FeedForwardBrain(env)

# %%
brain._build_graph()
brain.train_model()
# Out:
# episode 500 total reward 0.04 steps 6.61 eps: 0.01
# [[ 0.00242453  0.00797667  0.00332668  0.00675703]]
# episode 1000 total reward 0.0 steps 7.28 eps: 0.01
# [[ 0.00892022  0.00200843  0.00724661  0.00180897]]
# episode 1500 total reward 0.07 steps 12.86 eps: 0.01
# [[ 0.00892022  0.00269961  0.00797068  0.00180897]]
# episode 2000 total reward 0.04 steps 13.94 eps: 0.01
# [[ 0.01033297  0.04098957  0.00506293  0.00243361]]
# episode 2500 total reward 0.11 steps 19.47 eps: 0.01
# [[ 0.02382279  0.02423105  0.00584411  0.01590394]]
# episode 3000 total reward 0.07 steps 14.96 eps: 0.01
# [[ 0.01785625  0.01799356  0.00892022  0.01473519]]
# episode 3500 total reward 0.21 steps 24.88 eps: 0.01
# [[ 0.01785625  0.01799356  0.00892022  0.01415369]]
# episode 4000 total reward 0.14 steps 23.62 eps: 0.01
# [[ 0.02947125  0.02490204  0.00797667  0.02071065]]
# episode 4500 total reward 0.14 steps 28.48 eps: 0.01
# [[ 0.01981962  0.03713397  0.05479051  0.00243361]]
# ...

# %%
rolling_mean =  [ sum(brain.reward_history[i - 100 : i ])/100.0 for i in range(100, len(brain.reward_history))]

# %%
plt.plot(rolling_mean)

# %%
rolling_mean_steps =  [ sum(brain.step_history[i - 25 : i ])/25.0 for i in range(25, len(brain.step_history))]

# %%
plt.plot(rolling_mean_steps)

# %%
brain.model.saver.save(sess, "./tf_checkpts/model.ckpt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8d4697ee6829> in <module>()
# ----> 1 brain.model.saver.save(sess, "./tf_checkpts/model.ckpt")
#
# NameError: name 'sess' is not defined
