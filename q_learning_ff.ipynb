# %%
import gym
#from q_learning import FeedForwardBrain
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/mwoods/Developer/open-ai-gym/venv/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
env = gym.make('FrozenLake-v0')
# Out:
# [2016-12-04 21:55:30,964] Making new env: FrozenLake-v0

# %%
print env
# Out:
# <FrozenLakeEnv instance>

# %%
import q_learning

# %%
reload(q_learning)
brain = q_learning.FeedForwardBrain(env)

# %%
brain._build_graph()
brain.train_model()
# Out:
# episode 100 total reward 0.0 steps 5.45
# episode 200 total reward 0.0 steps 4.84
# episode 300 total reward 0.02 steps 5.05
# episode 400 total reward 0.01 steps 4.93
# episode 500 total reward 0.0 steps 4.83
# episode 600 total reward 0.01 steps 4.52
# episode 700 total reward 0.02 steps 4.95
# episode 800 total reward 0.01 steps 5.28
# episode 900 total reward 0.08 steps 5.95
# episode 1000 total reward 0.04 steps 5.69
# episode 1100 total reward 0.05 steps 6.43
# episode 1200 total reward 0.05 steps 5.67
# episode 1300 total reward 0.0 steps 6.17
# episode 1400 total reward 0.05 steps 6.13
# episode 1500 total reward 0.01 steps 6.61
# episode 1600 total reward 0.14 steps 19.56
# episode 1700 total reward 0.13 steps 18.04
# episode 1800 total reward 0.16 steps 20.88
# episode 1900 total reward 0.19 steps 21.98
# episode 2000 total reward 0.17 steps 18.37
# episode 2100 total reward 0.18 steps 24.95
# episode 2200 total reward 0.19 steps 21.92
# episode 2300 total reward 0.22 steps 29.78
# episode 2400 total reward 0.36 steps 29.96
# episode 2500 total reward 0.42 steps 29.96
# episode 2600 total reward 0.38 steps 31.42
# episode 2700 total reward 0.22 steps 28.1
# episode 2800 total reward 0.34 steps 27.15
# episode 2900 total reward 0.3 steps 26.56
# episode 3000 total reward 0.46 steps 34.73
# episode 3100 total reward 0.3 steps 29.8
# episode 3200 total reward 0.46 steps 34.56
# episode 3300 total reward 0.28 steps 16.56
# episode 3400 total reward 0.41 steps 27.92
# episode 3500 total reward 0.38 steps 27.91
# episode 3600 total reward 0.27 steps 23.24
# episode 3700 total reward 0.44 steps 30.14
# episode 3800 total reward 0.55 steps 35.0
# episode 3900 total reward 0.41 steps 27.96

# %%
rolling_mean =  [ sum(brain.reward_history[i - 25 : i ])/25.0 for i in range(25, len(brain.reward_history))]

# %%
plt.plot(rolling_mean)

# %%
rolling_mean_steps =  [ sum(brain.step_history[i - 25 : i ])/25.0 for i in range(25, len(brain.step_history))]

# %%
plt.plot(rolling_mean_steps)
